# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrapop01/DMP_Project/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Predicting admission to Masters Program from important parameters

# %% [markdown]
# *   This project was designed in order to help students in shortlisting universities with their profiles. The predicted output gives them a fair
# idea about their chances for a particular university.
#
# *   The data set contains several parameters which are considered important during the application for the Masters Program.
